# %% [markdown]
# <a href="https://colab.research.google.com/github/clout-13/phy329_darkenergy_final/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# %%
Omega_m0 = 0.34
Omega_r0 = 0.01
Omega_DE0 = 0.65

H_0 = 70

w_0 = -1
w_a = 0.1
